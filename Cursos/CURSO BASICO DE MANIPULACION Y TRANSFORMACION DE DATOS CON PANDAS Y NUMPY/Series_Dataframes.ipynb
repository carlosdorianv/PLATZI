# %%
import pandas as pd

# %%
psg_players = pd.Series(['Navas','Neymar','Mbappe','Messi'],
          index=[1,7,10,30]
          )

# %%
psg_players = pd.Series(['Navas','Neymar','Mbappe','Messi'],
          )

# %%
dict = {1:'Navas', 7:'Mbappe', 10:'Neymar',30:'Messi'}
pd.Series(dict)
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
psg_players[0:3]
# Out:
# 0     Navas
# 1    Neymar
# 2    Mbappe
# dtype: object

# %%
dict = {'Jugador':['Navas', 'Mbappe', 'Neymar','Messi'],
 'Altura': [183.0,170.0,170.0,165.0],
 'Goles' : [2,200,200,200]
 }

# %%
df_players = pd.DataFrame(dict,index=[1,7,10,30])

# %%
df_players.columns
# Out:
# Index(['Jugador', 'Altura', 'Goles'], dtype='object')

# %%
df_players.index
# Out:
# Int64Index([1, 7, 10, 30], dtype='int64')

# %%
pd
